# %%
import numpy as np
import pandas as pd
import torch

from loader import Loader
from datetime import datetime

from NMF import *

from tensorboardX import SummaryWriter
from sklearn.model_selection import train_test_split

# %%
# load data
df = pd.read_csv('../../data/buy_count.csv')
train, test = train_test_split(df, test_size=0.2, random_state=777)

train_x = train.to_numpy().astype(np.int32)
train_y = train['buy_count'].to_numpy().astype(np.float32)

test_x = test.to_numpy().astype(np.int32)
test_y = test['buy_count'].to_numpy().astype(np.float32)

n_user = int(len(df["user_id"].unique()))
n_item = 34
print('n_user======')
print(n_user)
print('n_item======')
print(n_item)
print("購買記錄_筆數")
print(len(df))
# Out:
# n_user======
# 3916
# n_item======
# 34
# 購買記錄_筆數
# 4438

# %%
# Hyer-parameters
lr = 1e-4
k = 5
batchsize = 256
max_epochs = 100
log_interval = 10

# %%
def update_parm(P, Q, train_x, k, lr):
    Q = Q.T
    for i in range(len(train_x)):
        current_user_index = torch.IntTensor(train_x[i, 0])
        current_item_index = torch.IntTensor(train_x[i, 1])
        current_tensor_P = P[current_user_index, :]
        current_tensor_Q = Q[:, current_item_index]
        eij = train_x[i, 2] - torch.sum(current_tensor_P * current_tensor_Q)
        for v_k in range(k):
            with torch.no_grad():
                P[current_user_index][v_k] = P[current_user_index][v_k] + \
                    2 * lr * eij * Q[v_k][current_item_index]
                Q[v_k][current_item_index] = Q[v_k][current_item_index] + \
                    2 * lr * eij * P[current_user_index][v_k]

# %%
# 定義模型
log_dir = '../runs/NMF_' + 'k=' + \
    str(k) + ',lr='+str(lr)+'batchsize='+str(batchsize) + \
    str(datetime.now()).replace(' ', '_')
writer = SummaryWriter(log_dir=log_dir)

model = NMF(n_user, n_item, k=k, writer=writer)

train_loader = Loader(
    train_x, train_y, batchsize=batchsize, do_shuffle=False)
test_loader = Loader(test_x, test_y, batchsize=batchsize, do_shuffle=False)

# %%
def training_loop(n_epochs, learning_rate, data_loader):
    iter = 0
    for epoch in range(n_epochs):
        for i, (train_x, train_y) in enumerate(data_loader):
            iter += 1
            prediction = model(train_x)
            loss = model.loss(
                prediction, train_x[:, 2])
            update_parm(model.P, model.Q, train_x=train_x, k=k, lr=lr)
            if iter % log_interval == 0:
                fmt = "Epoch[{}] Iteration[{}/{}] Loss: {:.2f}"
                msg = fmt.format(epoch, iter, len(
                    train_loader), loss)
                print(msg)
        # 驗證
        validation_loss = 0
        for i, (test_x, test_y) in enumerate(test_loader):
            ls = []
            for j in range(len(test_x)):
                current_user_index = torch.IntTensor(test_x[j, 0])
                current_item_index = torch.IntTensor(test_x[j, 1])
                current_tensor_P = model.P[current_user_index, :]
                current_tensor_Q = model.Q.T[:, current_item_index]
                pred = torch.sum(current_tensor_P * current_tensor_Q).item()
                ls.append(pred)
            result = torch.FloatTensor(ls)
            validation_loss += model.loss(result, test_y)
        mse = validation_loss/len(test_loader)
        print("Epoch[{}] Validation MSE: {:.2f} ".format(
            epoch+1, mse))
        writer.add_scalar("validation/avg_loss", mse, epoch)


training_loop(max_epochs, lr, train_loader)
# Save the model to a separate folder
torch.save(model.state_dict(), '../models/nmf.pth')
# Out:
# Epoch[0] Iteration[10/13] Loss: 1.33
# Epoch[1] Validation MSE: 1.22
# Epoch[1] Iteration[20/13] Loss: 2.32
# Epoch[2] Validation MSE: 1.21
# Epoch[2] Iteration[30/13] Loss: 2.11
# Epoch[3] Validation MSE: 1.21
# Epoch[3] Iteration[40/13] Loss: 0.99
# Epoch[3] Iteration[50/13] Loss: 1.24
# Epoch[4] Validation MSE: 1.20
# Epoch[4] Iteration[60/13] Loss: 1.39
# Epoch[5] Validation MSE: 1.20
# Epoch[5] Iteration[70/13] Loss: 1.93
# Epoch[6] Validation MSE: 1.20
# Epoch[6] Iteration[80/13] Loss: 2.26
# Epoch[6] Iteration[90/13] Loss: 1.48
# Epoch[7] Validation MSE: 1.19
# Epoch[7] Iteration[100/13] Loss: 1.22
# Epoch[8] Validation MSE: 1.19
# Epoch[8] Iteration[110/13] Loss: 2.10
# Epoch[9] Validation MSE: 1.19
# Epoch[9] Iteration[120/13] Loss: 2.14
# Epoch[9] Iteration[130/13] Loss: 1.33
# Epoch[10] Validation MSE: 1.19
# Epoch[10] Iteration[140/13] Loss: 1.27
# Epoch[11] Validation MSE: 1.19
# Epoch[11] Iteration[150/13] Loss: 2.23
# Epoch[12] Validation MSE: 1.19
# Epoch[12] Iteration[160/13] Loss: 2.01
# Epoch[13] Validation MSE: 1.18
# Epoch[13] Iteration[170/13] Loss: 0.94
# Epoch[13] Iteration[180/13] Loss: 1.23
# Epoch[14] Validation MSE: 1.18
# Epoch[14] Iteration[190/13] Loss: 1.36
# Epoch[15] Validation MSE: 1.18
# Epoch[15] Iteration[200/13] Loss: 1.90
# Epoch[16] Validation MSE: 1.18
# Epoch[16] Iteration[210/13] Loss: 2.22
# Epoch[16] Iteration[220/13] Loss: 1.44
# Epoch[17] Validation MSE: 1.18
# Epoch[17] Iteration[230/13] Loss: 1.19
# Epoch[18] Validation MSE: 1.18
# Epoch[18] Iteration[240/13] Loss: 2.06
# Epoch[19] Validation MSE: 1.18
# Epoch[19] Iteration[250/13] Loss: 2.11
# Epoch[19] Iteration[260/13] Loss: 1.30
# Epoch[20] Validation MSE: 1.18
# Epoch[20] Iteration[270/13] Loss: 1.25
# Epoch[21] Validation MSE: 1.18
# Epoch[21] Iteration[280/13] Loss: 2.18
# Epoch[22] Validation MSE: 1.18
# Epoch[22] Iteration[290/13] Loss: 1.96
# Epoch[23] Validation MSE: 1.18
# Epoch[23] Iteration[300/13] Loss: 0.92
# Epoch[23] Iteration[310/13] Loss: 1.22
# Epoch[24] Validation MSE: 1.18
# Epoch[24] Iteration[320/13] Loss: 1.35
# Epoch[25] Validation MSE: 1.17
# Epoch[25] Iteration[330/13] Loss: 1.88
# Epoch[26] Validation MSE: 1.17
# Epoch[26] Iteration[340/13] Loss: 2.18
# Epoch[26] Iteration[350/13] Loss: 1.42
# Epoch[27] Validation MSE: 1.17
# Epoch[27] Iteration[360/13] Loss: 1.18
# Epoch[28] Validation MSE: 1.17
# Epoch[28] Iteration[370/13] Loss: 2.03
# Epoch[29] Validation MSE: 1.17
# Epoch[29] Iteration[380/13] Loss: 2.08
# Epoch[29] Iteration[390/13] Loss: 1.28
# Epoch[30] Validation MSE: 1.17
# Epoch[30] Iteration[400/13] Loss: 1.24
# Epoch[31] Validation MSE: 1.17
# Epoch[31] Iteration[410/13] Loss: 2.15
# Epoch[32] Validation MSE: 1.17
# Epoch[32] Iteration[420/13] Loss: 1.93
# Epoch[33] Validation MSE: 1.17
# Epoch[33] Iteration[430/13] Loss: 0.90
# Epoch[33] Iteration[440/13] Loss: 1.21
# Epoch[34] Validation MSE: 1.17
# Epoch[34] Iteration[450/13] Loss: 1.33
# Epoch[35] Validation MSE: 1.17
# Epoch[35] Iteration[460/13] Loss: 1.86
# Epoch[36] Validation MSE: 1.17
# Epoch[36] Iteration[470/13] Loss: 2.16
# Epoch[36] Iteration[480/13] Loss: 1.40
# Epoch[37] Validation MSE: 1.17
# Epoch[37] Iteration[490/13] Loss: 1.16
# Epoch[38] Validation MSE: 1.17
# Epoch[38] Iteration[500/13] Loss: 2.00
# Epoch[39] Validation MSE: 1.17
# Epoch[39] Iteration[510/13] Loss: 2.05
# Epoch[39] Iteration[520/13] Loss: 1.26
# Epoch[40] Validation MSE: 1.17
# Epoch[40] Iteration[530/13] Loss: 1.22
# Epoch[41] Validation MSE: 1.17
# Epoch[41] Iteration[540/13] Loss: 2.13
# Epoch[42] Validation MSE: 1.17
# Epoch[42] Iteration[550/13] Loss: 1.90
# Epoch[43] Validation MSE: 1.17
# Epoch[43] Iteration[560/13] Loss: 0.89
# Epoch[43] Iteration[570/13] Loss: 1.20
# Epoch[44] Validation MSE: 1.17
# Epoch[44] Iteration[580/13] Loss: 1.32
# Epoch[45] Validation MSE: 1.17
# Epoch[45] Iteration[590/13] Loss: 1.84
# Epoch[46] Validation MSE: 1.17
# Epoch[46] Iteration[600/13] Loss: 2.13
# Epoch[46] Iteration[610/13] Loss: 1.38
# Epoch[47] Validation MSE: 1.17
# Epoch[47] Iteration[620/13] Loss: 1.15
# Epoch[48] Validation MSE: 1.17
# Epoch[48] Iteration[630/13] Loss: 1.98
# Epoch[49] Validation MSE: 1.17
# Epoch[49] Iteration[640/13] Loss: 2.03
# Epoch[49] Iteration[650/13] Loss: 1.25
# Epoch[50] Validation MSE: 1.17
# Epoch[50] Iteration[660/13] Loss: 1.21
# Epoch[51] Validation MSE: 1.17
# Epoch[51] Iteration[670/13] Loss: 2.10
# Epoch[52] Validation MSE: 1.17
# Epoch[52] Iteration[680/13] Loss: 1.88
# Epoch[53] Validation MSE: 1.17
# Epoch[53] Iteration[690/13] Loss: 0.88
# Epoch[53] Iteration[700/13] Loss: 1.19
# Epoch[54] Validation MSE: 1.17
# Epoch[54] Iteration[710/13] Loss: 1.31
# Epoch[55] Validation MSE: 1.17
# Epoch[55] Iteration[720/13] Loss: 1.82
# Epoch[56] Validation MSE: 1.17
# Epoch[56] Iteration[730/13] Loss: 2.10
# Epoch[56] Iteration[740/13] Loss: 1.36
# Epoch[57] Validation MSE: 1.17
# Epoch[57] Iteration[750/13] Loss: 1.14
# Epoch[58] Validation MSE: 1.17
# Epoch[58] Iteration[760/13] Loss: 1.96
# Epoch[59] Validation MSE: 1.17
# Epoch[59] Iteration[770/13] Loss: 2.00
# Epoch[59] Iteration[780/13] Loss: 1.23
# Epoch[60] Validation MSE: 1.17
# Epoch[60] Iteration[790/13] Loss: 1.20
# Epoch[61] Validation MSE: 1.17
# Epoch[61] Iteration[800/13] Loss: 2.08
# Epoch[62] Validation MSE: 1.17
# Epoch[62] Iteration[810/13] Loss: 1.85
# Epoch[63] Validation MSE: 1.17
# Epoch[63] Iteration[820/13] Loss: 0.87
# Epoch[63] Iteration[830/13] Loss: 1.18
# Epoch[64] Validation MSE: 1.17
# Epoch[64] Iteration[840/13] Loss: 1.30
# Epoch[65] Validation MSE: 1.17
# Epoch[65] Iteration[850/13] Loss: 1.81
# Epoch[66] Validation MSE: 1.17
# Epoch[66] Iteration[860/13] Loss: 2.08
# Epoch[66] Iteration[870/13] Loss: 1.34
# Epoch[67] Validation MSE: 1.17
# Epoch[67] Iteration[880/13] Loss: 1.13
# Epoch[68] Validation MSE: 1.17
# Epoch[68] Iteration[890/13] Loss: 1.93
# Epoch[69] Validation MSE: 1.17
# Epoch[69] Iteration[900/13] Loss: 1.98
# Epoch[69] Iteration[910/13] Loss: 1.22
# Epoch[70] Validation MSE: 1.17
# Epoch[70] Iteration[920/13] Loss: 1.18
# Epoch[71] Validation MSE: 1.17
# Epoch[71] Iteration[930/13] Loss: 2.06
# Epoch[72] Validation MSE: 1.17
# Epoch[72] Iteration[940/13] Loss: 1.83
# Epoch[73] Validation MSE: 1.17
# Epoch[73] Iteration[950/13] Loss: 0.86
# Epoch[73] Iteration[960/13] Loss: 1.17
# Epoch[74] Validation MSE: 1.17
# Epoch[74] Iteration[970/13] Loss: 1.29
# Epoch[75] Validation MSE: 1.17
# Epoch[75] Iteration[980/13] Loss: 1.79
# Epoch[76] Validation MSE: 1.17
# Epoch[76] Iteration[990/13] Loss: 2.06
# Epoch[76] Iteration[1000/13] Loss: 1.33
# Epoch[77] Validation MSE: 1.17
# Epoch[77] Iteration[1010/13] Loss: 1.12
# Epoch[78] Validation MSE: 1.17
# Epoch[78] Iteration[1020/13] Loss: 1.91
# Epoch[79] Validation MSE: 1.17
# Epoch[79] Iteration[1030/13] Loss: 1.95
# Epoch[79] Iteration[1040/13] Loss: 1.21
# Epoch[80] Validation MSE: 1.17
# Epoch[80] Iteration[1050/13] Loss: 1.17
# Epoch[81] Validation MSE: 1.17
# Epoch[81] Iteration[1060/13] Loss: 2.04
# Epoch[82] Validation MSE: 1.17
# Epoch[82] Iteration[1070/13] Loss: 1.81
# Epoch[83] Validation MSE: 1.17
# Epoch[83] Iteration[1080/13] Loss: 0.85
# Epoch[83] Iteration[1090/13] Loss: 1.17
# Epoch[84] Validation MSE: 1.17
# Epoch[84] Iteration[1100/13] Loss: 1.28
# Epoch[85] Validation MSE: 1.17
# Epoch[85] Iteration[1110/13] Loss: 1.77
# Epoch[86] Validation MSE: 1.17
# Epoch[86] Iteration[1120/13] Loss: 2.03
# Epoch[86] Iteration[1130/13] Loss: 1.31
# Epoch[87] Validation MSE: 1.17
# Epoch[87] Iteration[1140/13] Loss: 1.11
# Epoch[88] Validation MSE: 1.17
# Epoch[88] Iteration[1150/13] Loss: 1.89
# Epoch[89] Validation MSE: 1.17
# Epoch[89] Iteration[1160/13] Loss: 1.93
# Epoch[89] Iteration[1170/13] Loss: 1.20
# Epoch[90] Validation MSE: 1.17
# Epoch[90] Iteration[1180/13] Loss: 1.16
# Epoch[91] Validation MSE: 1.17
# Epoch[91] Iteration[1190/13] Loss: 2.01
# Epoch[92] Validation MSE: 1.17
# Epoch[92] Iteration[1200/13] Loss: 1.79
# Epoch[93] Validation MSE: 1.17
# Epoch[93] Iteration[1210/13] Loss: 0.85
# Epoch[93] Iteration[1220/13] Loss: 1.16
# Epoch[94] Validation MSE: 1.17
# Epoch[94] Iteration[1230/13] Loss: 1.28
# Epoch[95] Validation MSE: 1.17
# Epoch[95] Iteration[1240/13] Loss: 1.76
# Epoch[96] Validation MSE: 1.17
# Epoch[96] Iteration[1250/13] Loss: 2.01
# Epoch[96] Iteration[1260/13] Loss: 1.29
# Epoch[97] Validation MSE: 1.17
# Epoch[97] Iteration[1270/13] Loss: 1.10
# Epoch[98] Validation MSE: 1.17
# Epoch[98] Iteration[1280/13] Loss: 1.87
# Epoch[99] Validation MSE: 1.17
# Epoch[99] Iteration[1290/13] Loss: 1.91
# Epoch[99] Iteration[1300/13] Loss: 1.19
# Epoch[100] Validation MSE: 1.17
